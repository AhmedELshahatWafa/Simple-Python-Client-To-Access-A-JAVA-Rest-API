# %%
import requests as req
from IPython.display import Image

# %% [markdown]
# #  Get Structure

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getStructure"
resp = req.get(url)
print(resp.text)
# Out:
#       Structure of Wuzzuf_Jobs.csv
#  Index  |  Column Name  |  Column Type  |
# -----------------------------------------
#      0  |        Title  |       STRING  |
#      1  |      Company  |       STRING  |
#      2  |     Location  |       STRING  |
#      3  |         Type  |       STRING  |
#      4  |        Level  |       STRING  |
#      5  |     YearsExp  |       STRING  |
#      6  |      Country  |       STRING  |
#      7  |       Skills  |       STRING  |

# %% [markdown]
# # Get Summary

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getSummary"
resp = req.get(url)
print(resp.text.strip())
# Out:
# Wuzzuf_Jobs.csv
#   Summary   |    Title     |    Company     |  Location  |    Type     |     Level     |     YearsExp     |  Country  |                                                              Skills                                                               |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      Count  |        4380  |          4380  |      4380  |       4380  |         4380  |            4380  |     4380  |                                                                                                                             4380  |
# ...

# %% [markdown]
# # Get Jobs Per Company

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getJobsPerCompany"
resp = req.get(url)
print(resp.text)
# Out:
#                        Column: Company
#                      Category                      |  Count  |
# --------------------------------------------------------------
#                                      Confidential  |    590  |
#                                      Mishkat Nour  |     39  |
#                                       Expand Cart  |     35  |
#                                              EGIC  |     34  |
#                                       Aqarmap.com  |     25  |
#                                     Majorel Egypt  |     23  |
#  Ghassan Ahmed Alsulaiman for Electronic Services  |     21  |
#                                        Flairstech  |     18  |
#                               Profolio Consulting  |     17  |
#                                        OPPO Egypt  |     16  |

# %% [markdown]
# # Get Jobs Per Company PieChart

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getJobsPerCompanyPieChart"
resp = req.get(url)
s = str(resp.text)
s = s.replace("/","",1)  
Image(filename=s)

# %% [markdown]
# # Get Most Frequent Jobs

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getMostFrequentJobs"
resp = req.get(url)
print(resp.text)
# Out:
#                 Column: Title
#             Category              |  Count  |
# ---------------------------------------------
#                    iOS Developer  |      4  |
#       Technical Support Engineer  |      5  |
#            Senior Java Developer  |      5  |
#  IT Technical Support Specialist  |      5  |
#               Software Developer  |      6  |
#                    IT Specialist  |      6  |
#              Front End Developer  |      7  |
#      Senior Full Stack Developer  |      7  |
#          IT Help Desk Specialist  |      8  |
#             Senior iOS Developer  |      8  |

# %% [markdown]
# # Get Most Popular IT Jobs BarChart

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getMostPopITJobsBarChart"
resp = req.get(url)
s = str(resp.text)
s = s.replace("/","",1)  
Image(filename=s)

# %% [markdown]
# # Get Most Popular Areas

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getMostPopularAreas"
resp = req.get(url)
print(resp.text)
# Out:
#       Column: Location
#     Category     |  Count  |
# ----------------------------
#            Giza  |    126  |
#      Alexandria  |    130  |
#           Dokki  |    140  |
#     Mohandessin  |    140  |
#      Heliopolis  |    247  |
#  6th of October  |    282  |
#       Nasr City  |    424  |
#       New Cairo  |    522  |
#           Maadi  |    525  |
#           Cairo  |    563  |

# %% [markdown]
# # Get Most Popular Areas BarChart

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getMostPopularAreasBarChart"
resp = req.get(url)
s = str(resp.text)
s = s.replace("/","",1)  
Image(filename=s)

# %% [markdown]
# # Get Most Important Skill

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getMostImportantSkill"
resp = req.get(url)
print(resp.text)
# Out:
#  English Repeated 1236

# %% [markdown]
# # Get Exp NumCol

# %%
url="http://localhost:8080/demo4Cat_war_exploded/api/wuzzaf/getExpNumCol"
resp = req.get(url)
print(resp.text)
# Out:
# Column Added
